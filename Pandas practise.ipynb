# %%
import pandas as pd

# %%
df = pd.read_csv("pokemon_data.csv")
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Reading data

# %%
df['Name'][5]    #Charmeleon
df['Name'][0:5]  # is eqv to 'df.Name[0:5]'
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name','Type 1','Type 2','Generation']]
# Out:
#                       Name   Type 1  Type 2  Generation
# 0                Bulbasaur    Grass  Poison           1
# 1                  Ivysaur    Grass  Poison           1
# 2                 Venusaur    Grass  Poison           1
# 3    VenusaurMega Venusaur    Grass  Poison           1
# 4               Charmander     Fire     NaN           1
# ..                     ...      ...     ...         ...
# 795                Diancie     Rock   Fairy           6
# 796    DiancieMega Diancie     Rock   Fairy           6
# 797    HoopaHoopa Confined  Psychic   Ghost           6
# 798     HoopaHoopa Unbound  Psychic    Dark           6
# 799              Volcanion     Fire   Water           6
#
# [800 rows x 4 columns]

# %%
df.columns.values
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
for index, row in df.iterrows():
    print(index,row[['Name', 'Type 1']])
# Out:
# 0 Name      Bulbasaur
# Type 1        Grass
# Name: 0, dtype: object
# 1 Name      Ivysaur
# Type 1      Grass
# Name: 1, dtype: object
# 2 Name      Venusaur
# Type 1       Grass
# Name: 2, dtype: object
# 3 Name      VenusaurMega Venusaur
# Type 1                    Grass
# Name: 3, dtype: object
# 4 Name      Charmander
# Type 1          Fire
# Name: 4, dtype: object
# 5 Name      Charmeleon
# Type 1          Fire
# Name: 5, dtype: object
# 6 Name      Charizard
# Type 1         Fire
# Name: 6, dtype: object
# 7 Name      CharizardMega Charizard X
# Type 1                         Fire
# Name: 7, dtype: object
# 8 Name      CharizardMega Charizard Y
# Type 1                         Fire
# Name: 8, dtype: object
# 9 Name      Squirtle
# Type 1       Water
# Name: 9, dtype: object
# 10 Name      Wartortle
# Type 1        Water
# Name: 10, dtype: object
# 11 Name      Blastoise
# Type 1        Water
# Name: 11, dtype: object
# 12 Name      BlastoiseMega Blastoise
# ...

# %% [markdown]
# ### iloc:

# %%
df.iloc[3]       # values at index 3
df.iloc[3,:]     # values at index 3
df.iloc[3:6]     # from 3rd row to 5th row
df.iloc[3,1]     # at 3rd row, 1st column : VenusaurMega Venusaur
df.iloc[3:5,4:]
df.iloc[:,4:10]
df.iloc[[2,5],[4,6,8]]  # only index 2,5 and column num: 4,6,8
# Out:
#    HP  Defense  Sp. Def
# 2  80       83      100
# 5  58       58       65

# %%
df.iloc[3,4]==30
# Out:
# False

# %% [markdown]
# ### loc:

# %%
df.loc[0]        # same as df.iloc[3]
df.loc[3,:]      # same as df.iloc[3,:] or df.loc[3]
df.loc[0:3]      # same as df.iloc[0:3]
#df.loc[:,3:6] ------- not same as df.iloc[:,3:6]
#df.loc[3,1] --------- not same as df.iloc[3,1]
#df.loc[0:3,4:7] ----- not same as df.iloc[0:3,4:7]
#df.loc[0:3,4:] ------ not same as df.iloc[0:3,4:]

df.loc[0,'Type 1']                     # at row_label: 0, column_label: Type 1
df.loc[0:3, ['Type 1','HP','Attack']]  # from row_label 0-3 and selected column label
df.loc[0:3, 'Type 1':]                 # from row_label 0-3 and from column_label 'Type 1' to last
df.loc[0:3, 'Type 1':'Defense']        # from row_label 0-3 and from column_label 'Type 1' to 'Defense'
df.loc[[0,1,4], ['Type 1','Defense']]  # only row_labels 0,1,4 and column_label 'Type 1','Defense' --- eqv to iloc
# Out:
#   Type 1  Defense
# 0  Grass       49
# 1  Grass       63
# 4   Fire       43

# %%
df.loc[[2,5],['HP']]==30      # boolean result for row: 2,5 for column_label: HP, its False here
df.loc[2:5,['HP']]==30        # boolean result from row_label: 2-5 for column_label: HP, its False here
#df.loc['Name']=='Charmander' ---- won't work
df.loc[4]=='Charmander'       # boolean check for row_label:4 and all column at that index with 'Charmander'
# Out:
# #             False
# Name           True
# Type 1        False
# Type 2        False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# Name: 4, dtype: bool

# %%
# Difference between df.loc[...] AND df.loc[df[..]<condition>] is that: 
#        former is boolean check AND latter is display

df.loc[df['HP']<60]                # data display with HPless than 60
#df.loc[df['HP','Attack']<80]      # data display with HPless than 60 (not working)
df.loc[df['Type 1']=='Grass']      # data display with Type 1 has only Grass
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['Defense']>60)]   # multiple conditions with loc
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 452  407               Roserade  Grass  Poison   60      70       65      125
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 49        75     40           1      False
# 50        90     50           1      False
# ...

# %% [markdown]
# ## Changing data:

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Speed']
df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:,[4,5,6,9]].sum(axis=1)
df = df.drop(columns=['Total'])

cols = list(df.columns)                     # cols = df.columns NOT cols = list(df.columns)
df_modified = df[cols[4:7] + [cols[9]]]     # it's concatenation, not addition
df_modified.head()
# Out:
#    HP  Attack  Defense  Speed
# 0  45      49       49     45
# 1  60      62       63     60
# 2  80      82       83     80
# 3  80     100      123     80
# 4  39      52       43     65
